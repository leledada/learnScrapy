# %%
print('helloworld')
# Out:
# helloworld

# %%
import requests
url = 'https://weibo.com/a/hot/realtime'
cookie = 'SINAGLOBAL=7277049573002.714.1566888399893; ULV=1566888399907:1:1:1:7277049573002.714.1566888399893:; UOR=,,m.ali213.net; Ugrow-G0=7e0e6b57abe2c2f76f677abd9a9ed65d; SUB=_2AkMqLqVWf8NxqwJRmPAVxWPnaIpyyQnEieKcclSNJRMxHRl-yT83qkw-tRB6Aa6LuawfuCj-k3QH7mCtrqyw3Txr8kFF; SUBP=0033WrSXqPxfM72-Ws9jqgMF55529P9D9WWJrDJ8H0hrSpRG9GpmEzGF; YF-V5-G0=7e17aef9f70cd5c32099644f32a261c4'
user_agent = 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
headers = {'Cookie':cookie,'User-Agent':user_agent}
info = requests.get(url,headers = headers).text
print(info)
with open('weibo.html','w',encoding='utf-8')as f:
    f.write(info)
# Out:
# <!doctype html>
# <html>
# <head>
# 	<meta charset="utf-8">
# 	<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
# 	<meta name="viewport" content="initial-scale=1,minimum-scale=1" />
# 	<meta content="微博实时热点，聚合微博热搜榜精彩内容，第一时间了解最热微博明星、大V信息、微博最有趣的新鲜事。" name="description" />
# 	<link rel="mask-icon" sizes="any" href="//img.t.sinajs.cn/t6/style/images/apple/wbfont.svg" color="black" />
# 	<link rel="shortcut icon" type="image/x-icon" href="/favicon.ico" />
# 	<script type="text/javascript">
# 		try{document.execCommand("BackgroundImageCache", false, true);}catch(e){}
# 	</script>
# 		<title>微博实时热点_微博</title>
# 	<link href="//img.t.sinajs.cn/t6/style/css/module/base/frame.css?version=307744aa77dd5677" type="text/css" rel="stylesheet" charset="utf-8" />
# 	<link href="//img.t.sinajs.cn/t6/style/css/pages/growth/login_v5.css?version=307744aa77dd5677" type="text/css" rel="stylesheet" charset="utf-8">
# ...
